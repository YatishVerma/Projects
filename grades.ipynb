# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("grades.csv")

# %%
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %%
for column in df.columns:
    x=df[column].nunique()
    print(column,x)
# Out:
# Seat No. 571
# PH-121 13
# HS-101 12
# CY-105 13
# HS-105/12 13
# MT-111 13
# CS-105 11
# CS-106 13
# EL-102 13
# EE-119 12
# ME-107 13
# CS-107 14
# HS-205/20 13
# MT-222 14
# EE-222 13
# MT-224 14
# CS-210 14
# CS-211 14
# CS-203 13
# CS-214 13
# EE-217 13
# CS-212 12
# CS-215 14
# MT-331 12
# EF-303 12
# HS-304 14
# CS-301 12
# CS-302 11
# TC-383 12
# MT-442 12
# EL-332 13
# CS-318 14
# CS-306 13
# CS-312 14
# CS-317 12
# CS-403 11
# CS-421 13
# CS-406 14
# CS-414 13
# CS-419 12
# CS-423 12
# CS-412 13
# CGPA 491

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df, title="Profiling Report")

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.3&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-12-16 14:52:49.043289&quot;&gt;&lt;title&gt;Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
x=df.iloc[:,:-1]
y=df["CGPA"]

# %%
from sklearn.impute import SimpleImputer
for col in x:
    print(col)
    imputer = SimpleImputer(strategy='most_frequent')
    df[col] = imputer.fit_transform(df[col].values.reshape(-1, 1))[:, 0]
df.isnull().sum()
# Out:
# Seat No.
# PH-121
# HS-101
# CY-105
# HS-105/12
# MT-111
# CS-105
# CS-106
# EL-102
# EE-119
# ME-107
# CS-107
# HS-205/20
# MT-222
# EE-222
# MT-224
# CS-210
# CS-211
# CS-203
# CS-214
# EE-217
# CS-212
# CS-215
# MT-331
# EF-303
# HS-304
# CS-301
# CS-302
# TC-383
# MT-442
# EL-332
# CS-318
# CS-306
# CS-312
# CS-317
# CS-403
# CS-421
# CS-406
# CS-414
# CS-419
# CS-423
# CS-412
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# ...

# %%
for col in x:
    print(col)
    print(df[col].unique())
    print(df[col].nunique())
# Out:
# Seat No.
# ['CS-97001' 'CS-97002' 'CS-97003' 'CS-97004' 'CS-97005' 'CS-97006'
#  'CS-97007' 'CS-97008' 'CS-97009' 'CS-97010' 'CS-97011' 'CS-97012'
#  'CS-97013' 'CS-97014' 'CS-97015' 'CS-97016' 'CS-97017' 'CS-97018'
#  'CS-97019' 'CS-97020' 'CS-97021' 'CS-97022' 'CS-97023' 'CS-97024'
#  'CS-97025' 'CS-97026' 'CS-97027' 'CS-97028' 'CS-97029' 'CS-97030'
#  'CS-97031' 'CS-97032' 'CS-97033' 'CS-97034' 'CS-97035' 'CS-97036'
#  'CS-97037' 'CS-97038' 'CS-97039' 'CS-97040' 'CS-97041' 'CS-97042'
#  'CS-97043' 'CS-97044' 'CS-97045' 'CS-97046' 'CS-97047' 'CS-97048'
#  'CS-97049' 'CS-97050' 'CS-97051' 'CS-97052' 'CS-97053' 'CS-97054'
#  'CS-97055' 'CS-97056' 'CS-97057' 'CS-97058' 'CS-97059' 'CS-97060'
#  'CS-97061' 'CS-97062' 'CS-97063' 'CS-97064' 'CS-97065' 'CS-97066'
#  'CS-97067' 'CS-97068' 'CS-97069' 'CS-97070' 'CS-97071' 'CS-97072'
#  'CS-97073' 'CS-97074' 'CS-97075' 'CS-97076' 'CS-97077' 'CS-97078'
#  'CS-97079' 'CS-97080' 'CS-97081' 'CS-97082' 'CS-97083' 'CS-97084'
# ...

# %%
df.drop("Seat No.",axis=1,inplace=True)

# %%
# Define a dictionary that maps grades to numbers
grade_mapping = {
    'C-':6,
    'B+':5,
    'B-':3,
    'D':1, 
    'C' :7,
    'A-':9,
    'C+' :8,
    'D+':2, 
    'B':4, 
    'A' :10,
    'A+':11, 
    'I':0, 
    'WU':-2, 
    'F':0,
    'W':-1
}
for col in x:
    df[col]= df[col].map(grade_mapping)

# %%
x.drop("Seat No.",axis=1,inplace=True)

# %%
x=df.iloc[:,:-1]
y=df["CGPA"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.2,random_state=44)

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, BayesianRidge
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.decomposition import PCA
from sklearn.cross_decomposition import PLSRegression
import statsmodels.api as sm

# %%
from sklearn.pipeline import make_pipeline

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Ridge Regression": Ridge(alpha=1.0),
    "Lasso Regression": Lasso(alpha=0.1),
    "Bayesian Linear Regression": BayesianRidge(),
    "Principal Components Regression": make_pipeline(PCA(n_components=3), LinearRegression()),
    "Partial Least Squares Regression": PLSRegression(n_components=3),
    "Elastic Net Regression": ElasticNet(random_state=0),
    "Decision Tree Regression": DecisionTreeRegressor(random_state=0),
    "Random Forest Regression": RandomForestRegressor(random_state=0),
    "Support Vector Regression": SVR(),
}

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
for name,model in models.items():
    print(name)
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    mse=mean_squared_error(y_test,y_pred)
    R2=r2_score(y_test,y_pred)
    rmse=np.sqrt(mse)
    print("mean_squared_error =",mse)
    print("root_mean_squared_error =",rmse)
    print(" R2=",R2)
# Out:
# Linear Regression
# mean_squared_error = 0.08855363598084617
# root_mean_squared_error = 0.29757962964700085
#  R2= 0.7519861656225653
# Ridge Regression
# mean_squared_error = 0.08854487139557239
# root_mean_squared_error = 0.29756490282889947
#  R2= 0.7520107127614422
# Lasso Regression
# mean_squared_error = 0.08700044617104347
# root_mean_squared_error = 0.2949583804048352
#  R2= 0.7563362135452553
# Bayesian Linear Regression
# mean_squared_error = 0.0867088655228857
# root_mean_squared_error = 0.2944636913490111
#  R2= 0.7571528489524734
# Principal Components Regression
# mean_squared_error = 0.09518998284473572
# root_mean_squared_error = 0.30852873909043826
#  R2= 0.7333996241018093
# Partial Least Squares Regression
# mean_squared_error = 0.0864785512573307
# root_mean_squared_error = 0.2940723571798796
#  R2= 0.7577978944492441
# Elastic Net Regression
# mean_squared_error = 0.14731665721071507
# root_mean_squared_error = 0.3838185211929136
#  R2= 0.5874074664715252
# ...

# %%
from sklearn.model_selection import cross_val_score

for name, model in models.items():
    scores = cross_val_score(model, x, y, cv=5)  # 5-fold cross-validation
    print(f"{name}: Average R-squared score: {np.mean(scores)}")
# Out:
# Linear Regression: Average R-squared score: 0.8098332439714001
# Ridge Regression: Average R-squared score: 0.8098560153596752
# Lasso Regression: Average R-squared score: 0.7911512684824291
# Bayesian Linear Regression: Average R-squared score: 0.8151443381270085
# Principal Components Regression: Average R-squared score: 0.8013633526286916
# Partial Least Squares Regression: Average R-squared score: 0.8108411695182616
# Elastic Net Regression: Average R-squared score: 0.5710339530243933
# Decision Tree Regression: Average R-squared score: 0.6677831611192083
# Random Forest Regression: Average R-squared score: 0.8831389770274057
# Support Vector Regression: Average R-squared score: 0.835423128210832

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor


param_grid = {
    'n_estimators': [10, 50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt']
}

model = RandomForestRegressor()

grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)

grid_search.fit(x_train, y_train)

best_params = grid_search.best_params_

print(f"Best parameters: {best_params}")
# Out:
# C:\Users\yaris\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 720 fits failed out of a total of 1440.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 720 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\yaris\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\yaris\anaconda3\Lib\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "C:\Users\yaris\anaconda3\Lib\site-packages\sklearn\base.py", line 638, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor


param_grid = {
    'n_estimators': [10, 50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt']
}

model = RandomForestRegressor()

grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)

grid_search.fit(x, y)

best_params = grid_search.best_params_

print(f"Best parameters: {best_params}")
# Out:
# C:\Users\yaris\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 720 fits failed out of a total of 1440.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 720 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\yaris\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\yaris\anaconda3\Lib\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "C:\Users\yaris\anaconda3\Lib\site-packages\sklearn\base.py", line 638, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
fmodel = RandomForestRegressor(max_depth= None, max_features= 'sqrt', min_samples_leaf = 1, min_samples_split= 2, n_estimators= 50)
fmodel.fit(x_train,y_train)
y_predt=fmodel.predict(x_test)
mse=mean_squared_error(y_test,y_predt)
R2=r2_score(y_test,y_predt)
rmse=np.sqrt(mse)
print("mean_squared_error =",mse)
print("root_mean_squared_error =",rmse)
print(" R2=",R2)
# Out:
# mean_squared_error = 0.047751744918260855
# root_mean_squared_error = 0.21852172642156398
#  R2= 0.8662607895857299

# %%
ffmodel = RandomForestRegressor(max_depth= 30, max_features= 'sqrt', min_samples_leaf = 1, min_samples_split= 2, n_estimators= 200)
ffmodel.fit(x_train,y_train)
y_pret=fmodel.predict(x_test)
mse=mean_squared_error(y_test,y_pret)
R2=r2_score(y_test,y_pret)
rmse=np.sqrt(mse)
print("mean_squared_error =",mse)
print("root_mean_squared_error =",rmse)
print(" R2=",R2)
# Out:
# mean_squared_error = 0.047751744918260855
# root_mean_squared_error = 0.21852172642156398
#  R2= 0.8662607895857299

# %%
k=[4,404,303]
p=x.iloc[k]

# %%
fmodel.predict(p)
# Out:
# array([3.43128, 2.59336, 2.73536])

# %%
k=[4,404,303]
m=y.iloc[k]
print(m)
# Out:
# 4      3.448
# 404    2.548
# 303    2.736
# Name: CGPA, dtype: float64

# %%
import pickle

with open('grades.pkl', 'wb') as f:
    pickle.dump(fmodel, f)

# %%
with open('grades.pkl', 'rb') as f:
    loaded_model = pickle.load(f)

# %%
predictions = loaded_model.predict(p)

# %%
predictions
# Out:
# array([3.43128, 2.59336, 2.73536])
