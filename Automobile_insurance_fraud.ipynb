# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\yaris\DS\dataset\Automobile_insurance_fraud.csv" 
df=pd.read_csv(path)

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
date_col=["policy_bind_date","incident_date"]
for x in date_col:
    df[x]=pd.to_datetime(df[x],format="%d-%m-%Y")

# %%
num_column=df.select_dtypes(include=["float64","int64"]).columns.to_list()
cat_column=df.select_dtypes(include="object").columns.to_list()

# %%
for x in df.columns:
    count=df[x].nunique()
    print(x,count)
# Out:
# months_as_customer 391
# age 46
# policy_number 1000
# policy_bind_date 951
# policy_state 3
# policy_csl 3
# policy_deductable 3
# policy_annual_premium 991
# umbrella_limit 11
# insured_zip 995
# insured_sex 2
# insured_education_level 7
# insured_occupation 14
# insured_hobbies 20
# insured_relationship 6
# capital-gains 338
# capital-loss 354
# incident_date 60
# incident_type 4
# collision_type 4
# incident_severity 4
# authorities_contacted 4
# incident_state 7
# incident_city 7
# incident_location 1000
# incident_hour_of_the_day 24
# number_of_vehicles_involved 4
# property_damage 3
# bodily_injuries 3
# witnesses 4
# police_report_available 3
# total_claim_amount 763
# injury_claim 638
# property_claim 626
# vehicle_claim 726
# auto_make 14
# auto_model 39
# auto_year 21
# fraud_reported 2
# _c39 0

# %%
df.drop("_c39",axis=1,inplace=True)

# %%
num_column.remove("_c39")

# %%
df["fraud_reported"].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df["authorities_contacted"].value_counts()
# Out:
# authorities_contacted
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# Name: count, dtype: int64

# %%
df["authorities_contacted"].fillna("none",inplace=True)

# %%
for x in num_column:
    sns.histplot(df[x],bins=10)
    plt.show()

# %%
# for x in cat_column:
#     df[x].value_counts().plot(kind="bar")
#     plt.show()

# %%
for x in cat_column:
    pd.crosstab(df[x], df['fraud_reported'], normalize='index').plot(kind='bar', stacked=True, color=['blue', 'red'], width=0.8)

    # Add labels and title
    plt.xlabel(x)
    plt.ylabel('Percentage')
    plt.title(f'Fraud Reported Distribution by {x}')

    # Show the plot
    plt.show()

# %%
df["incident_location"].sample(100)
# Out:
# 113       5622 Best Ridge
# 431      9720 Lincoln Hwy
# 322     6309 Cherokee Ave
# 222      6634 Texas Ridge
# 101         7773 Tree Hwy
#               ...
# 122      5071 Flute Ridge
# 610        2063 Weaver St
# 460          9657 5th Ave
# 229      9610 Cherokee St
# 984    4475 Lincoln Ridge
# Name: incident_location, Length: 100, dtype: object

# %%
df_copy=df.copy()

# %%
df.drop("incident_location",axis=1,inplace=True)

# %%
df["policy_number"].nunique()
# Out:
# 1000

# %%
df.drop("policy_number",axis=1,inplace=True)
num_column.remove("policy_number")

# %%
# for x in num_column:
#     for y in num_column:
#         if x!=y:
#             sns.jointplot(x=df[x],y=df[y],kind="scatter",hue="fraud_reported",data= df)
#             plt.show()
#         else:
#             sns.kdeplot(df[x])

# %%
df_copy1=df.copy()

# %%
import pandas as pd
for x in num_column:
    print(x)
    Q1 = df_copy1[x].quantile(0.25)
    Q3 = df_copy1[x].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df_copy1 = df_copy1[(df_copy1[x] >= lower_bound) & (df_copy1[x] <= upper_bound)]
    outliers_count = ((df_copy1[x] < lower_bound) | (df_copy1[x] > upper_bound)).sum()
    print(f"Number of outliers in column {x}: {outliers_count}")
# Out:
# months_as_customer
# Number of outliers in column months_as_customer: 0
# age
# Number of outliers in column age: 0
# policy_deductable
# Number of outliers in column policy_deductable: 0
# policy_annual_premium
# Number of outliers in column policy_annual_premium: 0
# umbrella_limit
# Number of outliers in column umbrella_limit: 0
# insured_zip
# Number of outliers in column insured_zip: 0
# capital-gains
# Number of outliers in column capital-gains: 0
# capital-loss
# Number of outliers in column capital-loss: 0
# incident_hour_of_the_day
# Number of outliers in column incident_hour_of_the_day: 0
# number_of_vehicles_involved
# Number of outliers in column number_of_vehicles_involved: 0
# bodily_injuries
# Number of outliers in column bodily_injuries: 0
# witnesses
# Number of outliers in column witnesses: 0
# total_claim_amount
# Number of outliers in column total_claim_amount: 0
# injury_claim
# Number of outliers in column injury_claim: 0
# property_claim
# ...

# %%
df_copy1.shape
# Out:
# (783, 37)

# %%
count=(df_copy1 == '?').sum()
print(count)
# Out:
# months_as_customer               0
# age                              0
# policy_bind_date                 0
# policy_state                     0
# policy_csl                       0
# policy_deductable                0
# policy_annual_premium            0
# umbrella_limit                   0
# insured_zip                      0
# insured_sex                      0
# insured_education_level          0
# insured_occupation               0
# insured_hobbies                  0
# insured_relationship             0
# capital-gains                    0
# capital-loss                     0
# incident_date                    0
# incident_type                    0
# collision_type                 135
# incident_severity                0
# authorities_contacted            0
# incident_state                   0
# incident_city                    0
# incident_hour_of_the_day         0
# number_of_vehicles_involved      0
# property_damage                277
# bodily_injuries                  0
# ...

# %%
df_copy1.replace('?', np.nan, inplace=True)

# %%
for col in df_copy1.columns:
    if df_copy1[col].dtype in ['int64', 'float64']:
        df_copy1[col].fillna(df_copy1[col].mean(), inplace=True)
    elif df_copy1[col].dtype == 'object':
        df_copy1[col].fillna(df_copy1[col].mode()[0], inplace=True)

# %%
df_copy2=df_copy1.copy()

# %%
cat_column.remove("incident_location")

# %%
from sklearn.preprocessing import LabelEncoder
Label_Encoder=LabelEncoder()
df_copy2[cat_column]=df_copy2[cat_column].apply(Label_Encoder.fit_transform)

# %%
corr_matrix=df_copy2.corr()
plt.figure(figsize=(20, 20))
sns.heatmap(corr_matrix,annot=True,cmap="coolwarm",fmt=" .2f")
plt.title("correlation")
plt.show()

# %%
df_copy1.drop("umbrella_limit",axis=1,inplace=True)

# %%
num_column.remove("umbrella_limit")

# %%
x=df_copy1.drop("fraud_reported",axis=1)
y=df_copy1["fraud_reported"]

# %%
cat_column.remove("fraud_reported")

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import  train_test_split
from sklearn.preprocessing  import StandardScaler,OneHotEncoder,LabelEncoder
preprocessor=ColumnTransformer(transformers=[('num',StandardScaler(),num_column),
                                ('cat',OneHotEncoder(),cat_column)])
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=7)
x_train_transformed = preprocessor.fit_transform(x_train)
x_test_transformed = preprocessor.transform(x_test)

# %%
from sklearn.preprocessing import LabelEncoder
LabelEncode= LabelEncoder()
y_train_transformed = LabelEncode.fit_transform(y_train)
y_test_transformed = LabelEncode.transform(y_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix, precision_recall_curve,accuracy_score
from sklearn.model_selection import RepeatedStratifiedKFold
import matplotlib.pyplot as plt

# Create a list of classifiers
classifiers = [
    LogisticRegression(),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    ExtraTreesClassifier(),
    KNeighborsClassifier(),
    SVC(probability=True),
    AdaBoostClassifier(),
    GradientBoostingClassifier(),
]


from sklearn.metrics import roc_curve, roc_auc_score, accuracy_score, confusion_matrix
import seaborn as sns


for clf in classifiers:
    clf.fit(x_train_transformed, y_train_transformed)
    y_pred = clf.predict(x_test_transformed)
    y_prob = clf.predict_proba(x_test_transformed)[:, 1]  
    
    print(f"Classifier: {clf}")
    print(classification_report(y_test_transformed, y_pred))
    
    acc_score = accuracy_score(y_test_transformed, y_pred)*100
    print(f"Accuracy Score: {acc_score:.4f}\n")
    
    fpr, tpr, thresholds = roc_curve(y_test_transformed, y_prob)
    plt.figure(figsize=(8, 8))
    plt.plot(fpr, tpr, label=f'{clf} (AUC = {roc_auc_score(y_test_transformed, y_prob):.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')
    plt.show()

    # Confusion Matrix
    cm = confusion_matrix(y_test_transformed, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=['Predicted Negative', 'Predicted Positive'],
                yticklabels=['Actual Negative', 'Actual Positive'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()
    cm = confusion_matrix(y_test_transformed, y_pred)
    print(f"Confusion Matrix:\n{cm}\n")
# Out:
# Classifier: LogisticRegression()
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88       121
#            1       0.59      0.56      0.57        36
#
#     accuracy                           0.81       157
#    macro avg       0.73      0.72      0.72       157
# weighted avg       0.81      0.81      0.81       157
#
# Accuracy Score: 80.8917
# Confusion Matrix:
# [[107  14]
#  [ 16  20]]
#
# Classifier: DecisionTreeClassifier()
#               precision    recall  f1-score   support
#
#            0       0.90      0.83      0.86       121
#            1       0.54      0.69      0.61        36
#
#     accuracy                           0.80       157
#    macro avg       0.72      0.76      0.74       157
# weighted avg       0.82      0.80      0.80       157
#
# Accuracy Score: 79.6178
# Confusion Matrix:
# [[100  21]
#  [ 11  25]]
#
# Classifier: RandomForestClassifier()
# ...

# %%
from sklearn.model_selection import cross_val_score

# List of top 3 classifiers
top_classifiers = [
    AdaBoostClassifier(),
    RandomForestClassifier(),
    GradientBoostingClassifier()
]

# Cross-validation for the top 3 classifiers
for clf in top_classifiers:
    # Perform 5-fold cross-validation
    cv_scores = cross_val_score(clf, x_train_transformed, y_train_transformed, cv=5, scoring='accuracy')
    
    # Print average accuracy score
    print(f"Classifier: {clf.__class__.__name__}")
    print(f"Average Accuracy Score (Cross-Validation): {cv_scores.mean():.4f}\n")
# Out:
# Classifier: AdaBoostClassifier
# Average Accuracy Score (Cross-Validation): 0.7988
#
# Classifier: RandomForestClassifier
# Average Accuracy Score (Cross-Validation): 0.7715
#
# Classifier: GradientBoostingClassifier
# Average Accuracy Score (Cross-Validation): 0.8179

# %%
gb_classifier = GradientBoostingClassifier()

param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.5],
    'max_depth': [3, 4, 5],
    'subsample': [0.8, 1.0],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(estimator=gb_classifier, param_grid=param_grid, scoring='accuracy', cv=5)
grid_search.fit(x_train_transformed, y_train_transformed)

print("Best Hyperparameters:", grid_search.best_params_)
print("Best Cross-Validation Accuracy:", grid_search.best_score_)

best_model = grid_search.best_estimator_
test_accuracy = best_model.score(x_test_transformed, y_test_transformed)
print("Test Set Accuracy:", test_accuracy)
# Out:
# Best Hyperparameters: {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'subsample': 0.8}
# Best Cross-Validation Accuracy: 0.8354031746031746
# Test Set Accuracy: 0.8280254777070064

# %%
clf = GradientBoostingClassifier(learning_rate= 0.1,
                                 max_depth= 5, 
                                 min_samples_leaf= 1,
                                 min_samples_split = 2,
                                 n_estimators =100,
                                 subsample = 0.8)
clf.fit(x_train_transformed, y_train_transformed)
y_pred = clf.predict(x_test_transformed)
y_prob = clf.predict_proba(x_test_transformed)[:, 1]  
    
print(f"Classifier: {clf}")
print(classification_report(y_test_transformed, y_pred))
    
acc_score = accuracy_score(y_test_transformed, y_pred)*100
print(f"Accuracy Score: {acc_score:.4f}\n")
    
fpr, tpr, thresholds = roc_curve(y_test_transformed, y_prob)
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, label=f'{clf} (AUC = {roc_auc_score(y_test_transformed, y_prob):.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

    # Confusion Matrix
cm = confusion_matrix(y_test_transformed, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Predicted Negative', 'Predicted Positive'],
            yticklabels=['Actual Negative', 'Actual Positive'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
cm = confusion_matrix(y_test_transformed, y_pred)
print(f"Confusion Matrix:\n{cm}\n")
# Out:
# Classifier: GradientBoostingClassifier(max_depth=5, subsample=0.8)
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.89       121
#            1       0.63      0.72      0.68        36
#
#     accuracy                           0.84       157
#    macro avg       0.77      0.80      0.78       157
# weighted avg       0.85      0.84      0.84       157
#
# Accuracy Score: 84.0764
# Confusion Matrix:
# [[106  15]
#  [ 10  26]]
